# %% [markdown]
# # Libaries and prerequisites settings

# %%
import pandas as pd
import string
import re
from collections import defaultdict

# %%
# Kosaraju's algorithm to find strongly connected components in Python
# Code was modified from source : https://www.programiz.com/dsa/strongly-connected-components

class Graph:

    def __init__(self, vertex):
        self.V = vertex
        self.graph = defaultdict(list)

    def add_edge(self, s, d):
        self.graph[s].append(d)

    # dfs qui retourne le nombre de noeuds visités et donc fortement connexes
    def dfs(self, d, visited_vertex, reverse_dict):
        result_tab = [reverse_dict[d]];
        result_size = 1;
        visited_vertex[d] = True
        # print(reverse_dict[d], end=' ')
        for i in self.graph[d]:
            if not visited_vertex[i]:
                next_traversal = self.dfs(i, visited_vertex, reverse_mapping)
                result_tab,result_size = result_tab+next_traversal[0], result_size+next_traversal[1]
        return (result_tab,result_size)

    def fill_order(self, d, visited_vertex, stack):
        visited_vertex[d] = True
        for i in self.graph[d]:
            if not visited_vertex[i]:
                self.fill_order(i, visited_vertex, stack)
        stack = stack.append(d)

    # transposer la matrice
    def transpose(self):
        g = Graph(self.V)

        for i in self.graph:
            for j in self.graph[i]:
                g.add_edge(j, i)
        return g

    # trouver les satellites et le core
    def get_core_n_satellites(self, reverse_mapping, size=0):
        stack = []
        visited_vertex = [False] * (self.V)

        for i in range(self.V):
            if not visited_vertex[i]:
                self.fill_order(i, visited_vertex, stack)

        gr = self.transpose()

        visited_vertex = [False] * (self.V)
        res = [] # les satellites
        core_size = -1;
        core_ind = -1;
        core = [];
        
        while stack:
            i = stack.pop()
            if not visited_vertex[i]:
                current_strongly_connected = gr.dfs(i, visited_vertex, reverse_mapping)
                
                if(current_strongly_connected[1]) >= 2: # élimine les mots isolés / seuls
                    res.append(current_strongly_connected)
                    if(current_strongly_connected[1] > core_size):
                        core = current_strongly_connected[0]
                        core_size = current_strongly_connected[1]
                        core_ind = len(res)-1
                        
        del res[core_ind]
                
        return (core,res)

# %% [markdown]
# ## Data preparation

# %%
df = pd.read_csv("dictionary.csv");

# %%
df.head()
# Out:
#         word type                                         definition
# 0        Aam   n.  A Dutch and German measure of liquids, varying...
# 1  Aard-vark   n.  An edentate mammal, of the genus Orycteropus, ...
# 2  Aard-wolf   n.  A carnivorous quadruped (Proteles Lalandii), o...
# 3    Aaronic   a.                                  Alt. of Aaronical
# 4  Aaronical   a.  Pertaining to Aaron, the first high priest of ...

# %%
len(df)
# Out:
# 54544

# %%
df.drop_duplicates(subset=['word'])
n = len(df) # number of words
del df['type'] # we don't need it
print(n)
# Out:
# 54544

# %%
# lowercase characters
df['word'] = df['word'].str.lower()
df['definition'] = df['definition'].str.lower()


# take away special characters, except '-' for composed names and whitespaces
df['definition'].replace('[^-a-zA-Z\d\s:]','',regex=True, inplace=True)

# %%
df.head()
# Out:
#         word                                         definition
# 0        aam  a dutch and german measure of liquids varying ...
# 1  aard-vark  an edentate mammal of the genus orycteropus so...
# 2  aard-wolf  a carnivorous quadruped proteles lalandii of s...
# 3    aaronic                                   alt of aaronical
# 4  aaronical  pertaining to aaron the first high priest of t...

# %%
kernel = []
core = []
satellites = []

# %% [markdown]
# ## Kernel extraction & graph generation

# %%
dictionnary = dict() # the definition of each word
id_mapping = dict() # graph node - word mapping
reverse_mapping = dict()
ind = 0
for index, row in df.iterrows():
    id_mapping[row['word']] = ind
    reverse_mapping[ind] = row['word']
    ind += 1
    if(row['word'] in dictionnary):
        dictionnary[row['word']][1] += row['definition'].split()
    else:
        dictionnary[row['word']] = [0, row['definition'].split()] # first value will serve for later ( kernel or not ? ), second is definition

# %%
non_existants = set()
count_kernel = 0

for key,value in dictionnary.items():
    for word in value[1]:
        if word in dictionnary:
            if(value[0]==0):
                count_kernel+=1
                kernel.append(word)
            value[0] = 1
        else:
            non_existants.add(word)
print(len(dictionnary))
# Out:
# 34193

# %%
print("We see that there are , ", len(non_existants) , " non defined words in our dictionnary\nThis is not consisent with the assumption that a Dictionary (D) is a set of words and their definitions in which all the defined and defining words are defined.\nIf the Kernel size is too big, we might need to check a different dataset.")
# Out:
# We see that there are ,  27975  non defined words in our dictionnary
# This is not consisent with the assumption that a Dictionary (D) is a set of words and their definitions in which all the defined and defining words are defined.
# If the Kernel size is too big, we might need to check a different dataset.

# %%
print('Number of words in the kernel', str(count_kernel))
print("the past hypothesis was correct")
# Out:
# Number of words in the kernel 31329
# the past hypothesis was correct

# %%
kernel
# Out:
# ['german',
#  'genus',
#  'resembling',
#  'alt',
#  'first',
#  'rod',
#  'latin',
#  'fifth',
#  'also',
#  'red-hot',
#  'act',
#  'abaculus',
#  'abacus',
#  'back',
#  'radiate',
#  'large',
#  'abaculus',
#  'glass',
#  'abacus',
#  'abacus',
#  'table',
#  'rhinoceros',
#  'same',
#  'from',
#  'obeisance',
#  'abashed',
#  'from',
#  'act',
#  'univalve',
#  'abandon',
#  'abandon',
#  'abandon',
#  'reject',
#  'legally',
#  'act',
#  'forfeited',
#  'abnet',
#  'palm',
#  'alt',
#  'free',
#  'abase',
#  'abase',
#  'abase',
#  'abjectly',
#  'act',
#  'he',
#  'abash',
#  'abash',
#  'guilt',
#  'abashed',
#  'abashed',
#  'alt',
#  'about',
#  'abated',
#  'abate',
#  'abate',
#  'reduce',
#  'act',
#  'alt',
#  'formed',
#  'abatis',
#  'nuisance',
#  'abattoir',
#  'for',
#  'grass',
#  'rostrum',
#  'abashed',
#  'alt',
#  'from',
#  'upon',
#  'yarn',
#  'father',
#  'abbacy',
#  'jurisdiction',
#  'abbey',
#  'abbatial',
#  'french',
#  'female',
#  'abbey',
#  'from',
#  'head',
#  'abbot',
#  'abbreviate',
#  'abbreviate',
#  'abridge',
#  'act',
#  'reply',
#  'abbreviate',
#  'abbreviation',
#  'abb',
#  'first',
#  'religious',
#  'given',
#  'washing',
#  'abdicated',
#  'abdicating',
#  'abdicate',
#  'abdicate',
#  'relinquish',
#  'act',
#  'abdication',
#  'having',
#  'for',
#  'also',
#  'abdomen',
#  'abdominal',
#  'abdominal',
#  'group',
#  'abdomen',
#  'relating',
#  'having',
#  'abduce',
#  'abduce',
#  'abduct',
#  'abduct',
#  'take',
#  'act',
#  'form',
#  'right',
#  'up',
#  'learning',
#  'formed',
#  'abed',
#  'same',
#  'alt',
#  'alt',
#  'after',
#  'hibiscus',
#  'green',
#  'wander',
#  'alt',
#  'aberrant',
#  'wandering',
#  'go',
#  'act',
#  'aberration',
#  'machine',
#  'abet',
#  'abet',
#  'aid',
#  'act',
#  'abetment',
#  'alt',
#  'abeyance',
#  'abeyance',
#  'east',
#  'abominable',
#  'abhor',
#  'abhor',
#  'back',
#  'hatred',
#  'abhorrence',
#  'abhorring',
#  'abhorrence',
#  'first',
#  'abiding',
#  'abide',
#  'abide',
#  'abide',
#  'wait',
#  'resident',
#  'genus',
#  'from',
#  'fir',
#  'alt',
#  'resinous',
#  'abietin',
#  'resembling',
#  'habiliment',
#  'ability',
#  'able',
#  'alt',
#  'abyss',
#  'from',
#  'abiogenesis',
#  'life',
#  'generation',
#  'same',
#  'want',
#  'abirritation',
#  'abide',
#  'law',
#  'very',
#  'act',
#  'abject',
#  'take',
#  'reject',
#  'rejection',
#  'unyoke',
#  'act',
#  'abjuration',
#  'abjure',
#  'abjure',
#  'renounce',
#  'renunciation',
#  'from',
#  'lay',
#  'act',
#  'taking',
#  'ablatitious',
#  'taking',
#  'root',
#  'fire',
#  'fit',
#  'adjective',
#  'having',
#  'abroad',
#  'act',
#  'having',
#  'ability',
#  'able',
#  'alt',
#  'fresh-water',
#  'up',
#  'for',
#  'unlike',
#  'washing',
#  'ruddy',
#  'act',
#  'ablution',
#  'washed',
#  'able',
#  'abnegate',
#  'abnegate',
#  'reject',
#  'renunciation',
#  'renouncing',
#  'girdle',
#  'from',
#  'act',
#  'not',
#  'abnormality',
#  'abnormal',
#  'abnormal',
#  'abnormity',
#  'from',
#  'abnormal',
#  'hence',
#  'foreboding',
#  'foreboding',
#  'abolish',
#  'abolish',
#  'said',
#  'abolished',
#  'act',
#  'act',
#  'abolition',
#  'abolitionism',
#  'large',
#  'alt',
#  'fourth',
#  'abhorrence',
#  'abominable',
#  'abominable',
#  'abominate',
#  'abominate',
#  'from',
#  'feeling',
#  'above',
#  'from',
#  'accosting',
#  'first',
#  'aboriginal',
#  'native',
#  'abortment',
#  'abortive',
#  'forth',
#  'forth',
#  'act',
#  'agent',
#  'act',
#  'abortion',
#  'abortion',
#  'abortion',
#  'abortive',
#  'abortive',
#  'abortion',
#  'p',
#  'abound',
#  'abound',
#  'great',
#  'all',
#  'hammer',
#  'upper',
#  'above',
#  'hence',
#  'alt',
#  'named',
#  'recited',
#  'aback',
#  'figure',
#  'used',
#  'abrade',
#  'abrade',
#  'rub',
#  'alt',
#  'relating',
#  'alt',
#  'formerly',
#  'up',
#  'abranchiate',
#  'group',
#  'rubbed',
#  'act',
#  'abrasion',
#  'alt',
#  'red',
#  'used',
#  'abraid',
#  'men',
#  'abridge',
#  'renounce',
#  'absolute',
#  'joint',
#  'abridge',
#  'abridge',
#  'lessen',
#  'act',
#  'abroach',
#  'large',
#  'abrogated',
#  'abrogated',
#  'abrogate',
#  'abrogate',
#  'act',
#  'abrogate',
#  'act',
#  'very',
#  'abrupt',
#  'abrupt',
#  'abscess',
#  'result',
#  'removal',
#  'abscission',
#  'absciss',
#  'abscissa',
#  'abscissa',
#  'abscissa',
#  'reference',
#  'act',
#  'abscond',
#  'abscond',
#  'hide',
#  'fugitive',
#  'absent',
#  'from',
#  'absent',
#  'absent',
#  'absence',
#  'act',
#  'himself',
#  'absentee',
#  'absent',
#  'absent',
#  'absent',
#  'absent-minded',
#  'absinthic',
#  'alt',
#  'absinthium',
#  'absinthian',
#  'nature',
#  'absinthiated',
#  'relating',
#  'absinthium',
#  'use',
#  'absinthium',
#  'from',
#  'aloof',
#  'from',
#  'absolute',
#  'absolute',
#  'absolving',
#  'absolute',
#  'favor',
#  'absolutism',
#  'absolve',
#  'absolved',
#  'absolution',
#  'absolve',
#  'absolve',
#  'free',
#  'absolving',
#  'absorb',
#  'absorb',
#  'up',
#  'absorbable',
#  'absorbed',
#  'absorptiveness',
#  'absorbing',
#  'absorption',
#  'absorbed',
#  'act',
#  'having',
#  'absorptive',
#  'absorptiveness',
#  'take',
#  'used',
#  'abstain',
#  'abstain',
#  'hold',
#  'from',
#  'abstaining',
#  'abstemious',
#  'act',
#  'abstinence',
#  'hence',
#  'used',
#  'absterge',
#  'act',
#  'abstersive',
#  'act',
#  'abstinence',
#  'refraining',
#  'abstinence',
#  'from',
#  'abstract',
#  'abstract',
#  'abstracted',
#  'abstracted',
#  'abstract',
#  'act',
#  'abstraction',
#  'from',
#  'having',
#  'abstract',
#  'abstractive',
#  'abstract',
#  'abstract',
#  'unbind',
#  'hidden',
#  'abstruse',
#  'abstruse',
#  'act',
#  'abstruseness',
#  'gradually',
#  'act',
#  'reason',
#  'absurdity',
#  'absurd',
#  'absurd',
#  'absurdity',
#  'head',
#  'fullness',
#  'fully',
#  'fully',
#  'abused',
#  'abuse',
#  'abuse',
#  'abuse',
#  'use',
#  'full',
#  'various',
#  'usage',
#  'used',
#  'abusive',
#  'abusive',
#  'abut',
#  'abut',
#  'upon',
#  'genus',
#  'abutting',
#  'land',
#  'river',
#  'alt',
#  'for',
#  'abyss',
#  'resembling',
#  'fathomless',
#  'gulf',
#  'resembling',
#  'native',
#  'roll',
#  'acacia',
#  'acacia',
#  'alt',
#  'gum',
#  'academy',
#  'academic',
#  'academy',
#  'alt',
#  'school',
#  'academical',
#  'universities',
#  'academy',
#  'academic',
#  'academic',
#  'academic',
#  'academy',
#  'garden',
#  'scotia',
#  'also',
#  'acalephan',
#  'acalephan',
#  'alt',
#  'acalephae',
#  'group',
#  'resembling',
#  'alt',
#  'floral',
#  'same',
#  'fin',
#  'resembling',
#  'resembling',
#  'having',
#  'group',
#  'having',
#  'having',
#  'group',
#  'acanthopterygious',
#  'fishes',
#  'fishes',
#  'having',
#  'acanthus',
#  'acanthus',
#  'genus',
#  'said',
#  'having',
#  'heart',
#  'group',
#  'group',
#  'acari',
#  'resembling',
#  'having',
#  'not',
#  'acarus',
#  'genus',
#  'not',
#  'held',
#  'tailless',
#  'having',
#  'same',
#  'alt',
#  'same',
#  'race',
#  'accede',
#  'accede',
#  'forward',
#  'act',
#  'gradually',
#  'accelerate',
#  'accelerate',
#  'faster',
#  'act',
#  'relating',
#  'also',
#  'accelerative',
#  'for',
#  'for',
#  'fire',
#  'act',
#  'functionaries',
#  'force',
#  'accent',
#  'accent',
#  'accent',
#  'leading',
#  'accented',
#  'accent',
#  'accentual',
#  'accentual',
#  'accentuate',
#  'accentuate',
#  'accent',
#  'act',
#  'accept',
#  'accept',
#  'receive',
#  'acceptable',
#  'accepted',
#  'acceptable',
#  'acceptable',
#  'act',
#  'acceptance',
#  'accepting',
#  'acceptance',
#  'accepted',
#  'taker',
#  'gratuitous',
#  'acceptation',
#  'fit',
#  'after',
#  'near',
#  'accessary',
#  'accessary',
#  'accompanying',
#  'accessary',
#  'accessible',
#  'easy',
#  'accessible',
#  'act',
#  'accession',
#  'additional',
#  'accessory',
#  'accessory',
#  'accessory',
#  'accompanying',
#  'accessory',
#  'grace',
#  'grammar',
#  'foresight',
#  'happening',
#  'accidental',
#  'accidental',
#  'accidental',
#  'accidental',
#  'acipenser',
#  'receiver',
#  'accipiter',
#  'accipiter',
#  'genus',
#  'nature',
#  'accipitres',
#  'affected',
#  'acclaim',
#  'favor',
#  'acclamation',
#  'acclimated',
#  'acclimatization',
#  'acclimate',
#  'acclimate',
#  'habituate',
#  'acclimation',
#  'acclimated',
#  'acclimatized',
#  'act',
#  'acclimatize',
#  'acclimatize',
#  'habituate',
#  'act',
#  'acclivous',
#  'acclivous',
#  'acclivity',
#  'earth',
#  'upward',
#  'fill',
#  'lie',
#  'gather',
#  'formerly',
#  'accommodated',
#  'accommodable',
#  'accommodate',
#  'accommodate',
#  'render',
#  'fitly',
#  'fitness',
#  'act',
#  'he',
#  'he',
#  'added',
#  'accompanying',
#  'accompany',
#  'accompany',
#  'go',
#  'accomplish',
#  'accessory',
#  'accomplice',
#  'act',
#  'accomplish',
#  'accomplish',
#  'full',
#  'accomplished',
#  'act',
#  'account',
#  'accountable',
#  'accountant',
#  'agreement',
#  'accord',
#  'accord',
#  'agreeing',
#  'agreement',
#  'accordance',
#  'agreeing',
#  'accordance',
#  'agreeably',
#  'keyed',
#  'accordion',
#  'agreement',
#  'unite',
#  'accost',
#  'accost',
#  'join',
#  'affable',
#  'women',
#  'reckoning',
#  'account',
#  'account',
#  'accountable',
#  'liable',
#  'accountable',
#  'accountable',
#  'accountant',
#  'account',
#  'accountant',
#  'kept',
#  'join',
#  'act',
#  'accoutre',
#  'accoutre',
#  'accoutre',
#  'accoutre',
#  'alt',
#  'furnish',
#  'alt',
#  'render',
#  'accredit',
#  'accredit',
#  'sanction',
#  'act',
#  'generation',
#  'accrue',
#  'growth',
#  'growing',
#  'grow',
#  'act',
#  'relating',
#  'accuse',
#  'hook',
#  'usurpation',
#  'accrument',
#  'accrue',
#  'accrue',
#  'growth',
#  'act',
#  'accruing',
#  'act',
#  'recline',
#  'accumbent',
#  'leaning',
#  'accumulate',
#  'accumulate',
#  'heap',
#  'act',
#  'accumulation',
#  'for',
#  'accurate',
#  'requirement',
#  'accurate',
#  'accurate',
#  'upon',
#  'alt',
#  'hence',
#  'liable',
#  'accusation',
#  'accuser',
#  'act',
#  'accusative',
#  'accusatory',
#  'accusative',
#  'accusatory',
#  'accusation',
#  'accusation',
#  'accusation',
#  'accuse',
#  'accuse',
#  'accusation',
#  'fault',
#  'accusing',
#  'accustom',
#  'accustom',
#  'familiar',
#  'habitual',
#  'according',
#  'habitual',
#  'usual',
#  'habituation',
#  'ace',
#  'unit',
#  'field',
#  'not',
#  'acephala',
#  'called',
#  'same',
#  'fabulous',
#  'no',
#  'larval',
#  'resembling',
#  'headless',
#  'aceric',
#  'harsh',
#  'harshness',
#  'unripe',
#  'from',
#  'having',
#  'same',
#  'heap',
#  'heap',
#  'heaping',
#  'heaped',
#  'full',
#  'resembling',
#  'alt',
#  'acescent',
#  'readily',
#  'acetabulum',
#  'acetabuliform',
#  'furnished',
#  'furnished',
#  'acetabuliform',
#  'hip',
#  'from',
#  'acetic',
#  'from',
#  'acetyl',
#  'used',
#  'acid',
#  'salt',
#  'acetic',
#  'acetic',
#  'act',
#  'for',
#  'acetify',
#  'acetify',
#  'acid',
#  'for',
#  'act',
#  'acetic',
#  'acetify',
#  'same',
#  'hydrogen',
#  'acetone',
#  'acetous',
#  'acetous',
#  'having',
#  'hypothetical',
#  'gaseous',
#  'alt',
#  'name',
#  'alt',
#  'greece',
#  'savage',
#  'agate',
#  'genus',
#  'acater',
#  'ache',
#  'ache',
#  'achaean',
#  'alt',
#  'fruit',
#  'achene',
#  'river',
#  'acheron',
#  'achieved',
#  'achievement',
#  'achieve',
#  'achieve',
#  'final',
#  'act',
#  'resembling',
#  'formed',
#  'also',
#  'not',
#  'naked',
#  'want',
#  'lacking',
#  'free',
#  'achromatic',
#  'achromatism',
#  'not',
#  'achromatic',
#  'act',
#  'achromatize',
#  'achromatize',
#  'achromatic',
#  'acronyc',
#  'not',
#  'achromatic',
#  'acicula',
#  'also',
#  'needle',
#  'alt',
#  'furnished',
#  'acicular',
#  'needle',
#  'having',
#  'high',
#  'yielding',
#  'acidified',
#  'acidity',
#  'act',
#  'necessary',
#  'acidify',
#  'acidify',
#  'acid',
#  'for',
#  'law',
#  'acidity',
#  'acidity',
#  'acidulate',
#  'acidulate',
#  'acid',
#  'having',
#  'acidulous',
#  'needle',
#  'grains',
#  'saber',
#  'acinaciform',
#  'same',
#  'group',
#  'resembling',
#  'having',
#  'alt',
#  'acini',
#  'acinus',
#  'grains',
#  'genus',
#  'recognize',
#  'acknowledge',
#  'acknowledge',
#  'admit',
#  'act',
#  'said',
#  'height',
#  'affection',
#  'not',
#  'up',
#  'hanging',
#  'acology',
#  'science',
#  'acolythist',
#  'form',
#  'has',
#  'same',
#  'acolyte',
#  'alt',
#  'jointless',
#  'nature',
#  'herb',
#  'same',
#  'aconite',
#  'alkaloid',
#  'herb',
#  'largely',
#  'called',
#  'relieving',
#  'fruit',
#  'acorn',
#  'furnished',
#  'genus',
#  'universe',
#  'universe',
#  'has',
#  'having',
#  'agouti',
#  'for',
#  'hearing',
#  'hearing',
#  'acoustics',
#  'relation',
#  'versed',
#  'science',
#  'acquainted',
#  'acquaint',
#  'acquaint',
#  'easy',
#  'acquainted',
#  'acquainted',
#  'acquaintance',
#  'acquainted',
#  'acquisition',
#  'acquiesce',
#  'acquiesce',
#  'rest',
#  'from',
#  'acquiescent',
#  'resting',
#  'acquiescent',
#  'acquirable',
#  'acquired',
#  'acquire',
#  'acquire',
#  'gain',
#  'act',
#  'acquirement',
#  'acquired',
#  'act',
#  'acquired',
#  'acquisition',
#  'acquisitive',
#  'acquisition',
#  'acquitted',
#  'acquit',
#  'acquit',
#  'acquittal',
#  'act',
#  'release',
#  'absence',
#  'wanting',
#  'alt',
#  'alt',
#  'group',
#  'field',
#  'acre',
#  'acreage',
#  'landed',
#  'harsh',
#  'alt',
#  'acrid',
#  'acid',
#  'acrid',
#  'acrimonious',
#  ...]

# %% [markdown]
# ## Core extraction

# %%
g = Graph(n)
for key,value in dictionnary.items():
    for word in value[1]:
        if word in dictionnary:
            g.add_edge((id_mapping[key]),(id_mapping[word]))
core_sat = g.get_core_n_satellites(reverse_mapping)
core = core_sat[0]
print("The number of words in the core is ", str(len(core_sat[0])))
print("Those words are : ")
print(core)
# Out:
# The number of words in the core is  5618
# Those words are :
# ['german', 'accent', 'acute', 'acuteness', 'gravity', 'aluminium', 'alum', 'aluminous', 'hornblende', 'foliation', 'feathering', 'feather', 'calamus', 'rattan', 'umbilicus', 'navel', 'nave', 'aisle', 'screen', 'fight', 'abstraction', 'absence', 'calm', 'allay', 'allayed', 'unlaid', 'nettles', 'acalephae', 'acalephan', 'acalephs', 'jellyfish', 'umbrella', 'frame', 'abacus', 'aback', 'jam', 'jammed', 'jar', 'jarred', 'jug', 'large', 'abroad', 'air', 'absent', 'absent-minded', 'abstract', 'abstracted', 'remote', 'abstruse', 'recess', 'alcove', 'fireplace', 'gather', 'amass', 'accumulate', 'accumulated', 'accumulation', 'gain', 'access', 'accessible', 'accessibility', 'familiar', 'accustomed', 'forbearing', 'forbearance', 'abstinence', 'fast', 'adhere', 'adhered', 'routine', 'groove', 'flute', 'flageolet', 'recorder', 'register', 'calendar', 'almanac', 'calends', 'calendula', 'goolde', 'gold', 'abuse', 'abused', 'license', 'allow', 'admit', 'accept', 'accepted', 'acceptable', 'acceptability', 'acceptableness', 'acceptance', 'acceptation', 'adoption', 'adopted', 'adopt', 'adopting', 'echo', 'echoed', 'resound', 'resonant', 'resonance', 'nasal', 'hum', 'humming', 'ruby', 'agate', 'nonpareil', 'reglet', 'fillet', 'fascia', 'filleting', 'flashing', 'flash', 'flashed', 'flashes', 'gleam', 'glimmer', 'glimmering', 'ghost', 'haunt', 'hay', 'aftermath', 'aftergrass', 'fog', 'lift', 'cage', 'lantern', 'rung', 'range', 'jet', 'fountain', 'font', 'face', 'about', 'acre', 'vesture', 'vest', 'vested', 'age', 'adult', 'rising', 'aerial', 'airy', 'airily', 'lightly', 'finger', 'ablution', 'washing', 'accretion', 'nucleus', 'karyoplasma', 'nucleoplasm', 'kernel', 'grain', 'badger', 'gray', 'fasciola', 'fluke', 'flook', 'palm', 'cabbage', 'cabbaged', 'head', 'academy', 'academic', 'academical', 'formality', 'ease', 'abandon', 'abandoned', 'abandonment', 'reprobate', 'reprobated', 'reprobation', 'satire', 'aim', 'address', 'accost', 'greet', 'advance', 'advanced', 'abreast', 'against', 'admonish', 'admonishing', 'warning', 'admonition', 'advertisement', 'notification', 'hatchment', 'achievement', 'field', 'adjacent', 'adjoining', 'neighbor', 'call', 'ahem', 'alarm', 'affray', 'fray', 'fret', 'fretted', 'ripple', 'rippled', 'rippling', 'rumble', 'grumble', 'grouse', 'gallinae', 'gallinaceous', 'rasores', 'hen', 'cackling', 'cackle', 'cake', 'fadge', 'fay', 'fairy', 'fairies', 'mad', 'frantic', 'frenzy', 'fanaticism', 'fanatic', 'fanatical', 'rabid', 'hydrophobia', 'rabies', 'ultra', 'ultraist', 'zealot', 'zeal', 'abate', 'abated', 'abatement', 'addition', 'accession', 'add', 'accelerate', 'accelerated', 'acceleration', 'fever', 'ague', 'c', 'f', 'b', 'administer', 'administered', 'free', 'absolve', 'forgive', 'forgiven', 'forgiveness', 'relentless', 'rigor', 'horror', 'horrible', 'grim', 'frown', 'frowning', 'rugged', 'obdurate', 'hard', 'acanthopterygious', 'scomber', 'mackerel', 'garfish', 'gar', 'gorebill', 'greenbone', 'hornfish', 'needlefish', 'earl', 'graf', 'lady', 'faint', 'fade', 'faded', 'fresh', 'alga', 'algae', 'fruit', 'acorn', 'oak', 'aged', 'youthful', 'juvenile', 'young', 'babe', 'baby', 'nativity', 'calculate', 'calculating', 'calculation', 'account', 'accounted', 'accountable', 'accountability', 'responsible', 'father', 'after', 'acceptor', 'accepter', 'gage', 'greengage', 'wage', 'waged', 'game', 'backgammon', 'gammon', 'hit', 'guess', 'guessed', 'guessing', 'riddle', 'key', 'adjunct', 'adjective', 'adjectively', 'none', 'force', 'abduct', 'abducting', 'abduction', 'forcible', 'forcibly', 'hail', 'halting', 'faltering', 'hesitation', 'falter', 'hesitate', 'halt', 'halted', 'hitch', 'hitched', 'hobble', 'hobbling', 'lame', 'founder', 'gravel', 'alluvium', 'alluvial', 'amber', 'ambered', 'yellowish', 'fawn-colored', 'fawn', 'honey', 'hive', 'gum', 'gamboge', 'lacquer', 'japan', 'hydrangea', 'neuter', 'neutral', 'hydrate', 'hydrating', 'gelatine', 'gelatin', 'frill', 'ruffle', 'fluted', 'cabling', 'cable', 'fleet', 'admiral', 'admira ...

# %% [markdown]
# ## Satellites exctraction

# %%
satellites = core_sat[1]
number = len(satellites)
print("The are is total ", str(number), " satellite sets")
for i in range(number):
    print("Set number ", str(i+1), " of size ", str(satellites[i][1]), str(satellites[i][0]))
# Out:
# The are is total  619  satellite sets
# Set number  1  of size  2 ['zincic', 'zincous']
# Set number  2  of size  2 ['zante', 'zantewood']
# Set number  3  of size  2 ['yonker', 'younker']
# Set number  4  of size  2 ['yeomanlike', 'yeomanly']
# Set number  5  of size  2 ['xylene', 'xylol']
# Set number  6  of size  2 ['xiphosura', 'xiphura']
# Set number  7  of size  2 ['xiphiplastron', 'xiphisternum']
# Set number  8  of size  2 ['xiphoid', 'xiphoidian']
# Set number  9  of size  2 ['xanthorhiza', 'yellowroot']
# Set number  10  of size  2 ['xanthelasma', 'xanthoma']
# Set number  11  of size  2 ['water-ret', 'water-rot']
# Set number  12  of size  2 ['wasite', 'wasium']
# Set number  13  of size  2 ['washboard', 'wasteboard']
# Set number  14  of size  2 ['yelp', 'yaup']
# Set number  15  of size  2 ['vicinal', 'vicine']
# Set number  16  of size  2 ['viameter', 'viatometer']
# Set number  17  of size  2 ['vesiculose', 'vesiculous']
# Set number  18  of size  2 ['vesicular', 'vesiculate']
# Set number  19  of size  2 ['vesicant', 'vesicatory']
# Set number  20  of size  2 ['verticillate', 'verticillated']
# Set number  21  of size  2 ['verrucose', 'verrucous']
# Set number  22  of size  3 ['verderer', 'vert', 'verderor']
# Set number  23  of size  2 ['verbiage', 'verbosity']
# Set number  24  of size  2 ['verbena', 'vervain']
# Set number  25  of size  2 ['verbally', 'verbatim']
# Set number  26  of size  2 ['ventricose', 'ventricous']
# Set number  27  of size  2 ['veinous', 'veiny']
# Set number  28  of size  2 ['vasodilator', 'vaso-inhibitory']
# Set number  29  of size  3 ['variolar', 'variolous', 'variolic']
# Set number  30  of size  2 ['vanadic', 'vanadious']
# Set number  31  of size  2 ['valvelet', 'valvule']
# Set number  32  of size  2 ['valeric', 'valerianic']
# Set number  33  of size  2 ['vaginate', 'vaginated']
# Set number  34  of size  3 ['vagabondage', 'vagabondism', 'vagrancy']
# Set number  35  of size  2 ['utricular', 'utriculate']
# Set number  36  of size  2 ['usherdom', 'ushership']
# Set number  37  of size  2 ['uredo', 'urticaria']
# Set number  38  of size  2 ['uranographic', 'uranographical']
# Set number  39  of size  2 ['uranography', 'uranology']
# Set number  40  of size  2 ['uranic', 'uranous']
# Set number  41  of size  3 ['upbreak', 'upburst', 'uprush']
# Set number  42  of size  2 ['unswaddle', 'unswathe']
# Set number  43  of size  2 ['unslacked', 'unslaked']
# Set number  44  of size  2 ['unnest', 'unnestle']
# Set number  45  of size  2 ['unmerchantable', 'unsalable']
# Set number  46  of size  2 ['unkard', 'unked']
# Set number  47  of size  2 ['uniformitarianism', 'uniformitarian']
# Set number  48  of size  2 ['unheal', 'unhele']
# Set number  49  of size  2 ['unhallowed', 'unholy']
# Set number  50  of size  2 ['unfetter', 'unshackle']
# Set number  51  of size  2 ['undershirt', 'undervest']
# Set number  52  of size  2 ['underline', 'underscore']
# Set number  53  of size  2 ['undecennary', 'undecennial']
# Set number  54  of size  3 ['uncinata', 'uncinus', 'uncini']
# Set number  55  of size  2 ['unbar', 'unbolt']
# Set number  56  of size  2 ['unanimous', 'unanimity']
# Set number  57  of size  2 ['umbra', 'umbrine']
# Set number  58  of size  2 ['umbellate', 'umbellated']
# Set number  59  of size  2 ['ululate', 'ululating']
# Set number  60  of size  2 ['ubiquitarian', 'ubiquitist']
# Set number  61  of size  2 ['tagbelt', 'tagsore']
# Set number  62  of size  2 ['tacamahac', 'tacamahaca']
# Set number  63  of size  2 ['tabetic', 'tabid']
# Set number  64  of size  2 ['scypha', 'scyphus']
# Set number  65  of size  3 ['scutella', 'scutellum', 'scutum']
# Set number  66  of size  3 ['scutched', 'scutch', 'scutching']
# Set number  67  of size  2 ['scup', 'scuppaug']
# Set number  68  of size  2 ['scud', 'scudding']
# Set number  69  of size  2 ['scribe', 'scribing']
# Set number  70  of size  2 ['scranny', 'scrawny']
# Set number  71  of size  2 ['scragged', 'scraggy']
# Set number  72  of size  2 ['scorbutic', 'scorbutical']
# Set number  73  of size  2 ['sclerotic', 'sclerotical']
# Set number  74  of size  2 ['sciagraph', 'sciagraphy']
# Set number  75  of size  2 ['schizopod', 'schizopodous']
# Set number  76  of size  2 ['scepterless', 'sceptreless']
# Set number  77  of size  3 ['scarab', 'scarabee', 'scarabaeus']
# Set number  78  of size  2 ['scapular', 'scapulary']
# Set number  79  of size  6 ['scamble', 'scambling', 'scrambling', 'scramble', 'scrabble', 'scrabbling']
# Set number  80  of size  3 ['scribble', 'scrawl', 'scribbling']
# Set number  81  of size  2 ['scallop', 'scalloped']
# Set number  82  of size  2 ['scale-winged', 'scaly-winged']
# Set number  83  of size  2 ['scalar', 'vector']
# Set number  84  of size  2 ['saw-set', 'saw-wrest']
# Set number  85  of size  2 ['sawer', 'sawyer']
# Set number  86  of size  2 ['satyric', 'satyrical']
# Set number  87  of size  3 ['sarlac', 'yak', 'sarlyk']
# Set number  88  of size  2 ['saunter', 'sauntering']
# Set number  89  of size  2 ['santalic', 'santalin']
# Set number  90  of size  2 ['saneness', 'sanity']
# Set number  91  of size  2 ['sanatorium', 'sanitarium']
# Set number  92  of size  2 ['sambo', 'zambo']
# Set number  93  of size  3 ['salivation', 'salivate', 'salivating']
# Set number  94  of size  3 ['salicylal', 'salicylol', 'salicylous']
# Set number  95  of size  2 ['salian', 'salic']
# Set number  96  of size  2 ['sagathy', 'sayette']
# Set number  97  of size  2 ['sachem', 'sagamore']
# Set number  98  of size  2 ['utriculus', 'utricle']
# Set number  99  of size  2 ['saccholactic', 'saccholic']
# Set number  100  of size  2 ['saccharonic', 'saccharone']
# Set number  101  of size  2 ['saccharin', 'saccharinic']
# Set number  102  of size  2 ['ruthenic', 'ruthenious']
# Set number  103  of size  5 ['ruralize', 'rusticate', 'rusticated', 'rustication', 'rusticating']
# Set number  104  of size  2 ['rugae', 'ruga']
# Set number  105  of size  2 ['sandalwood', 'santalum']
# Set number  106  of size  3 ['rubric', 'rubrical', 'rubricate']
# Set number  107  of size  2 ['round-backed', 'round-shouldered']
# Set number  108  of size  2 ['roun', 'rown']
# Set number  109  of size  2 ['rota', 'rotta']
# Set number  110  of size  2 ['roseroot', 'rosewort']
# Set number  111  of size  2 ['rondeau', 'rondo']
# Set number  112  of size  3 ['scot', 'scotchman', 'scotsman']
# Set number  113  of size  2 ['rollic', 'rollicking']
# Set number  114  of size  3 ['rokeage', 'yokeage', 'rokee']
# Set number  115  of size  2 ['riveled', 'rivel']
# Set number  116  of size  2 ['rip', 'ripping']
# Set number  117  of size  2 ['ringsail', 'ringtail']
# Set number  118  of size  2 ['rhododendron', 'rosebay']
# Set number  119  of size  3 ['rhapsodist', 'rhapsody', 'rhapsodies']
# Set number  120  of size  2 ['rhubarb', 'rheum']
# Set number  121  of size  5 ['revestiary', 'vestry', 'sacristy', 'vestryman', 'vestrymen']
# Set number  122  of size  2 ['revery', 'reverie']
# Set number  123  of size  2 ['retrofract', 'retrofracted']
# Set number  124  of size  2 ['retinacula', 'retinaculum']
# Set number  125  of size  2 ['retaliative', 'retaliatory']
# Set number  126  of size  2 ['resolvability', 'resolvableness']
# Set number  127  of size  2 ['republicanized', 'republicanize']
# Set number  128  of size  2 ['replicate', 'replicated']
# Set number  129  of size  3 ['replevied', 'replevin', 'replevy']
# Set number  130  of size  2 ['remold', 'remould']
# Set number  131  of size  2 ['remand', 'remanding']
# Set number  132  of size  2 ['reillume', 'reillumine']
# Set number  133  of size  2 ['reformative', 'reformatory']
# Set number  134  of size  3 ['urus', 'ure', 'ur']
# Set number  135  of size  2 ['reedbuck', 'rietboc']
# Set number  136  of size  2 ['reduplicate', 'reduplicative']
# Set number  137  of size  3 ['redleg', 'redshank', 'redlegs']
# Set number  138  of size  2 ['rediae', 'redia']
# Set number  139  of size  2 ['red-hand', 'red-handed']
# Set number  140  of size  2 ['redeye', 'rudd']
# Set number  141  of size  2 ['redeemability', 'redeemableness']
# Set number  142  of size  2 ['recti', 'rectus']
# Set number  143  of size  2 ['rectoress', 'rectrix']
# Set number  144  of size  2 ['rectorate', 'rectorship']
# Set number  145  of size  2 ['recto', 'verso']
# Set number  146  of size  2 ['recoup', 'recoupe']
# Set number  147  of size  2 ['reclinate', 'reclined']
# Set number  148  of size  2 ['recapture', 'retake']
# Set number  149  of size  2 ['reassurance', 'reinsurance']
# Set number  150  of size  2 ['rearmouse', 'reremouse']
# Set number  151  of size  2 ['razorback', 'rorqual']
# Set number  152  of size  3 ['retrenching', 'retrenchment', 'retrench']
# Set number  153  of size  2 ['rase', 'rasing']
# Set number  154  of size  2 ['rummage', 'romage']
# Set number  155  of size  3 ['ramp', 'ramping', 'rampant']
# Set number  156  of size  2 ['ramal', 'rameal']
# Set number  157  of size  2 ['rale', 'rhonchus']
# Set number  158  of size  2 ['radicate', 'radicated']
# Set number  159  of size  2 ['raddle', 'ruddle']
# Set number  160  of size  2 ['rachitis', 'rickets']
# Set number  161  of size  2 ['rabato', 'rebato']
# Set number  162  of size  2 ['palmin', 'ricinolein']
# Set number  163  of size  2 ['palmer', 'palmerworm']
# Set number  164  of size  2 ['pallah', 'roodebok']
# Set number  165  of size  2 ['palladic', 'palladious']
# Set number  166  of size  2 ['paleographer', 'paleographist']
# Set number  167  of size  2 ['pachometer', 'pachymeter']
# Set number  168  of size  2 ['numb', 'numbness']
# Set number  169  of size  2 ['nucleate', 'nucleated']
# Set number  170  of size  2 ['noways', 'nowise']
# Set number  171  of size  2 ['nouthe', 'nowthe']
# Set number  172  of size  2 ['nosebleed', 'yarrow']
# Set number  173  of size  2 ['nonstriated', 'unstriped']
# Set number  174  of size  2 ['non-', 'un-']
# Set number  175  of size  2 ['nonsuit', 'nonsuited']
# Set number  176  of size  2 ['unprecedented', 'unexampled']
# Set number  177  of size  2 ['unspeakable', 'unutterable']
# Set number  178  of size  3 ['nomarch', 'nomarchy', 'nome']
# Set number  179  of size  2 ['nitrocarbol', 'nitromethane']
# Set number  180  of size  3 ['nitrobenzene', 'nitrobenzole', 'nitrobenzol']
# Set number  181  of size  2 ['nicotic', 'nicotinic']
# Set number  182  of size  2 ['nickelic', 'nickelous']
# Set number  183  of size  2 ['nervation', 'neuration']
# Set number  184  of size  2 ['neptunian', 'neptunist']
# Set number  185  of size  2 ['nephritical', 'nephritic']
# Set number  186  of size  2 ['rationalist', 'reasonist']
# Set number  187  of size  2 ['retributive', 'retributory']
# Set number  188  of size  3 ['nemertina', 'nemertida', 'rhynchocoela']
# Set number  189  of size  2 ['nematogene', 'rhombogene']
# Set number  190  of size  2 ['neif', 'neaf']
# Set number  191  of size  3 ['needlewoman', 'seamstress', 'needlework']
# Set number  192  of size  3 ['veronica', 'vernacle', 'vernicle']
# Set number  193  of size  2 ['nebule', 'nebuly']
# Set number  194  of size  2 ['nebulae', 'nebula']
# Set number  195  of size  2 ['neb', 'nib']
# Set number  196  of size  2 ['sapodilla', 'sapota']
# Set number  197  of size  2 ['naphthalene', 'naphthaline']
# Set number  198  of size  3 ['nacker', 'nacre', 'naker']
# Set number  199  of size  2 ['mackle', 'macule']
# Set number  200  of size  2 ['maccabean', 'maccabees']
# Set number  201  of size  2 ['liege', 'liegeman']
# Set number  202  of size  2 ['liane', 'liana']
# Set number  203  of size  2 ['leuco-', 'leuc-']
# Set number  204  of size  3 ['leuchaemia', 'leucocythemia', 'leucocythaemia']
# Set number  205  of size  2 ['lettic', 'lettish']
# Set number  206  of size  2 ['leopardwood', 'letterwood']
# Set number  207  of size  2 ['lecythis', 'sapucaia']
# Set number  208  of size  3 ['lectern', 'lecturn', 'lettern']
# Set number  209  of size  2 ['lecanoric', 'lecanorin']
# Set number  210  of size  2 ['lawyerlike', 'lawyerly']
# Set number  211  of size  2 ['lawgiver', 'legislator']
# Set number  212  of size  2 ['lavatic', 'lavic']
# Set number  213  of size  2 ['lark', 'larking']
# Set number  214  of size  2 ['lar', 'lares']
# Set number  215  of size  2 ['laplander', 'lapp']
# Set number  216  of size  2 ['lampas', 'lampers']
# Set number  217  of size  2 ['lambskinnet', 'lansquenet']
# Set number  218  of size  2 ['lambda', 'lambdoid']
# Set number  219  of size  2 ['sagittal', 'rabdoidal']
# Set number  220  of size  2 ['ladykin', 'lakin']
# Set number  221  of size  2 ['ladybird', 'ladybug']
# Set number  222  of size  2 ['lacunose', 'lacunous']
# Set number  223  of size  3 ['laconic', 'laconical', 'laconism']
# Set number  224  of size  2 ['lachrymatory', 'lacrymal']
# Set number  225  of size  2 ['lac', 'lakh']
# Set number  226  of size  2 ['labyrinthodon', 'labyrinthodonta']
# Set number  227  of size  2 ['labyrinthal', 'labyrinthian']
# Set number  228  of size  2 ['kidneywort', 'navelwort']
# Set number  229  of size  3 ['kenogenesis', 'palingenesy', 'palingenesis']
# Set number  230  of size  2 ['keeve', 'kier']
# Set number  231  of size  3 ['regressive', 'retrogression', 'retrogressive']
# Set number  232  of size  2 ['reticular', 'retiform']
# Set number  233  of size  3 ['karyokinesis', 'nuclear', 'karyostenosis']
# Set number  234  of size  2 ['kamsin', 'khamsin']
# Set number  235  of size  3 ['kamichi', 'palamedeae', 'screamer']
# Set number  236  of size  2 ['kaka', 'nestor']
# Set number  237  of size  2 ['kail', 'kale']
# Set number  238  of size  2 ['juglone', 'nucin']
# Set number  239  of size  2 ['jougs', 'juggs']
# Set number  240  of size  2 ['joe', 'johannes']
# Set number  241  of size  4 ['veratrine', 'sabadilla', 'veratria', 'veratrina']
# Set number  242  of size  2 ['jaunt', 'jaunting']
# Set number  243  of size  2 ['jamacina', 'jamaicine']
# Set number  244  of size  2 ['jacqueminot', 'remontant']
# Set number  245  of size  2 ['jacksnipe', 'juddock']
# Set number  246  of size  2 ['jacare', 'yacare']
# Set number  247  of size  2 ['hyrcanian', 'hyrcan']
# Set number  248  of size  3 ['hypothecated', 'hypothecation', 'hypothecate']
# Set number  249  of size  2 ['hypotenuse', 'hypothenuse']
# Set number  250  of size  2 ['hypostatic', 'hypostatical']
# Set number  251  of size  2 ['hypoplastron', 'hyposternum']
# Set number  252  of size  2 ['hypodicrotic', 'hypodicrotous']
# Set number  253  of size  2 ['hypocraterimorphous', 'salver-shaped']
# Set number  254  of size  2 ['hypersthene', 'schiller']
# Set number  255  of size  2 ['hypaxial', 'hyposkeletal']
# Set number  256  of size  2 ['hymeneal', 'hymenean']
# Set number  257  of size  2 ['hygrometric', 'hygrometrical']
# Set number  258  of size  2 ['hydrometric', 'hydrometrical']
# Set number  259  of size  3 ['hydrobilirubin', 'urobilin', 'urochrome']
# Set number  260  of size  2 ['hydro-', 'hydr-']
# Set number  261  of size  2 ['huffed', 'huff']
# Set number  262  of size  3 ['housewife', 'housewive', 'hussy']
# Set number  263  of size  2 ['horrified', 'horrify']
# Set number  264  of size  2 ['hooven', 'hoven']
# Set number  265  of size  2 ['hurrah', 'huzza']
# Set number  266  of size  2 ['honorarium', 'honorary']
# Set number  267  of size  3 ['radicle', 'rootlet', 'radicel']
# Set number  268  of size  2 ['homoorgan', 'homoplast']
# Set number  269  of size  2 ['homomorphy', 'homophyly']
# Set number  270  of size  2 ['homoiousian', 'homoousian']
# Set number  271  of size  2 ['homographic', 'homography']
# Set number  272  of size  2 ['homogeny', 'homoplasy']
# Set number  273  of size  2 ['sciatic', 'sciatica']
# Set number  274  of size  2 ['holly', 'holm']
# Set number  275  of size  2 ['hogback', 'hogframe']
# Set number  276  of size  3 ['hod', 'scuttle', 'scuddle']
# Set number  277  of size  2 ['hoard', 'hoarding']
# Set number  278  of size  2 ['histogenesis', 'histogeny']
# Set number  279  of size  2 ['histiology', 'histology']
# Set number  280  of size  2 ['hircic', 'hircin']
# Set number  281  of size  2 ['hippobosca', 'horsefly']
# Set number  282  of size  2 ['hindi', 'hindustani']
# Set number  283  of size  2 ['hexene', 'hexylene']
# Set number  284  of size  2 ['nereis', 'nereid']
# Set number  285  of size  2 ['heterogenesis', 'homogenesis']
# Set number  286  of size  2 ['heterodont', 'homodont']
# Set number  287  of size  2 ['heroicomic', 'heroicomical']
# Set number  288  of size  3 ['hermetic', 'hermetical', 'hermetically']
# Set number  289  of size  2 ['hermeneutic', 'hermeneutical']
# Set number  290  of size  2 ['hereto', 'hereunto']
# Set number  291  of size  2 ['hereon', 'hereupon']
# Set number  292  of size  2 ['heptene', 'heptylene']
# Set number  293  of size  2 ['hepatogenic', 'hepatogenous']
# Set number  294  of size  2 ['roost', 'roosting']
# Set number  295  of size  2 ['undecylic', 'undecyl']
# Set number  296  of size  2 ['henceforth', 'henceforward']
# Set number  297  of size  3 ['hellgamite', 'neuroptera', 'hellgramite']
# Set number  298  of size  2 ['heliolatry', 'sabianism']
# Set number  299  of size  2 ['hecdecane', 'hexadecane']
# Set number  300  of size  2 ['henbane', 'hyoscyamus']
# Set number  301  of size  2 ['pall', 'pallium']
# Set number  302  of size  2 ['headstock', 'tailstock']
# Set number  303  of size  2 ['haybote', 'hedgebote']
# Set number  304  of size  3 ['hausen', 'huso', 'huchen']
# Set number  305  of size  2 ['hatteria', 'rhynchocephala']
# Set number  306  of size  2 ['hasp', 'padlock']
# Set number  307  of size  2 ['hemispherical', 'hemispheric']
# Set number  308  of size  2 ['handicapped', 'handicap']
# Set number  309  of size  4 ['ham', 'hamstring', 'hock', 'hough']
# Set number  310  of size  2 ['keratose', 'keratode']
# Set number  311  of size  2 ['hastate', 'hastated']
# Set number  312  of size  3 ['halo', 'halos', 'nimbus']
# Set number  313  of size  3 ['haggle', 'haggling', 'higgle']
# Set number  314  of size  3 ['haematoin', 'haematolin', 'haematoporphyrin']
# Set number  315  of size  2 ['hematoidin', 'haemolutein']
# Set number  316  of size  2 ['hematocrya', 'hematotherma']
# Set number  317  of size  5 ['warm-blooded', 'haematothermal', 'homoiothermal', 'homothermous', 'homothermic']
# Set number  318  of size  2 ['hemadynamometer', 'haemomanometer']
# Set number  319  of size  2 ['haemad', 'neurad']
# Set number  320  of size  2 ['haema-', 'haemo-']
# Set number  321  of size  3 ['haematogenesis', 'hematosis', 'sanguification']
# Set number  322  of size  2 ['haemapodous', 'neuropodous']
# Set number  323  of size  2 ['harquebus', 'harquebuse']
# Set number  324  of size  2 ['habergeon', 'hauberk']
# Set number  325  of size  2 ['gyroscope', 'rotascope']
# Set number  326  of size  3 ['lias', 'jurassic', 'jura']
# Set number  327  of size  2 ['gyrus', 'gyri']
# Set number  328  of size  2 ['gunroom', 'wardroom']
# Set number  329  of size  2 ['gyneocracy', 'gynecocracy']
# Set number  330  of size  2 ['gully', 'gullies']
# Set number  331  of size  2 ['guideboard', 'guidepost']
# Set number  332  of size  2 ['gurgle', 'gurgling']
# Set number  333  of size  2 ['guelph', 'guelf']
# Set number  334  of size  2 ['guanaco', 'huanaco']
# Set number  335  of size  2 ['grumose', 'grumous']
# Set number  336  of size  2 ['grudgeons', 'gurgeons']
# Set number  337  of size  3 ['grouper', 'jewfish', 'warsaw']
# Set number  338  of size  3 ['grunt', 'grunter', 'redmouth']
# Set number  339  of size  2 ['gride', 'griding']
# Set number  340  of size  2 ['grewsome', 'gruesome']
# Set number  341  of size  2 ['grenadier', 'rat-tail']
# Set number  342  of size  2 ['grosbeak', 'hawfinch']
# Set number  343  of size  2 ['grecized', 'grecize']
# Set number  344  of size  2 ['grecism', 'hellenism']
# Set number  345  of size  7 ['grayling', 'umber', 'umbre', 'umbriere', 'umbrere', 'umbril', 'umbrette']
# Set number  346  of size  3 ['gratulate', 'gratulating', 'gratulation']
# Set number  347  of size  2 ['granulite', 'leptynite']
# Set number  348  of size  2 ['grallae', 'grallatores']
# Set number  349  of size  2 ['gowdnook', 'saury']
# Set number  350  of size  2 ['gospelized', 'gospelize']
# Set number  351  of size  2 ['gorgerin', 'hypotrachelium']
# Set number  352  of size  2 ['gordius', 'hairworm']
# Set number  353  of size  2 ['goody', 'lafayette']
# Set number  354  of size  2 ['gonorrheal', 'gonorrhoeal']
# Set number  355  of size  2 ['gonangium', 'gonotheca']
# Set number  356  of size  2 ['gome', 'gorm']
# Set number  357  of size  2 ['goldtit', 'verdin']
# Set number  358  of size  2 ['goldfinny', 'goldsinny']
# Set number  359  of size  3 ['goggle-eye', 'goggler', 'scad']
# Set number  360  of size  4 ['robin', 'redbreast', 'robinet', 'ruddock']
# Set number  361  of size  2 ['godhead', 'godhood']
# Set number  362  of size  2 ['goatsucker', 'nightjar']
# Set number  363  of size  2 ['goatish', 'goatlike']
# Set number  364  of size  2 ['goaf', 'gob']
# Set number  365  of size  2 ['gnome', 'goblin']
# Set number  366  of size  3 ['zeolite', 'heulandite', 'natrolite']
# Set number  367  of size  2 ['glycoluric', 'hydantoic']
# Set number  368  of size  3 ['glycin', 'glycocoll', 'glycocin']
# Set number  369  of size  2 ['glycide', 'glycidic']
# Set number  370  of size  6 ['glutton', 'gormandize', 'gormandizing', 'gormandizer', 'gourmand', 'gormand']
# Set number  371  of size  3 ['glottal', 'glottidean', 'glottic']
# Set number  372  of size  2 ['glossology', 'glottology']
# Set number  373  of size  2 ['glonoin', 'glonoine']
# Set number  374  of size  7 ['globulin', 'hematin', 'haematin', 'hemoglobin', 'haemoglobin', 'hematocrystallin', 'haematocrystallin']
# Set number  375  of size  2 ['noctiluca', 'noctilucae']
# Set number  376  of size  2 ['gliadin', 'glutin']
# Set number  377  of size  2 ['glisten', 'glistening']
# Set number  378  of size  3 ['glasswort', 'kali', 'salsola']
# Set number  379  of size  2 ['glass-rope', 'hyalonema']
# Set number  380  of size  3 ['haze', 'hazed', 'hazy']
# Set number  381  of size  2 ['gladiate', 'gladiolus']
# Set number  382  of size  3 ['gypsy', 'gypsies', 'romany']
# Set number  383  of size  3 ['gyp', 'scout', 'scouting']
# Set number  384  of size  2 ['licorice', 'glycyrrhiza']
# Set number  385  of size  3 ['ginglyform', 'ginglymoidal', 'ginglymoid']
# Set number  386  of size  2 ['jingle', 'jingling']
# Set number  387  of size  2 ['guilder', 'gulden']
# Set number  388  of size  2 ['gigot', 'giggot']
# Set number  389  of size  2 ['gizzard', 'gigerium']
# Set number  390  of size  2 ['geometer', 'geometrician']
# Set number  391  of size  4 ['geodesical', 'geodesic', 'geodetical', 'geodetic']
# Set number  392  of size  4 ['geocentric', 'geocentrical', 'heliocentrical', 'heliocentric']
# Set number  393  of size  3 ['genitourinary', 'urinogenital', 'urogenital']
# Set number  394  of size  2 ['genevan', 'genevese']
# Set number  395  of size  5 ['gein', 'humin', 'humic', 'ulmin', 'ulmic']
# Set number  396  of size  2 ['geanticlinal', 'geosynclinal']
# Set number  397  of size  2 ['gawk', 'gawky']
# Set number  398  of size  2 ['gauffer', 'goffer']
# Set number  399  of size  2 ['viburnum', 'laurestine']
# Set number  400  of size  2 ['gastrohepatic', 'hepatogastric']
# Set number  401  of size  2 ['gastroenteric', 'gastrointestinal']
# Set number  402  of size  2 ['gastraea', 'gastrula']
# Set number  403  of size  2 ['hypoblast', 'hypoderm']
# Set number  404  of size  2 ['gasometric', 'gasometrical']
# Set number  405  of size  2 ['garrot', 'golden-eye']
# Set number  406  of size  2 ['gargle', 'gargling']
# Set number  407  of size  5 ['warble', 'warbling', 'yodle', 'yodeling', 'yodel']
# Set number  408  of size  2 ['rinse', 'rinsing']
# Set number  409  of size  2 ['gantline', 'girtline']
# Set number  410  of size  2 ['lashing', 'lasher']
# Set number  411  of size  3 ['galloway', 'garran', 'garron']
# Set number  412  of size  3 ['hotchpotch', 'hotchpot', 'hodgepodge']
# Set number  413  of size  2 ['hash', 'hashed']
# Set number  414  of size  3 ['galician', 'gallego', 'gallegan']
# Set number  415  of size  2 ['galanga', 'galangal']
# Set number  416  of size  2 ['galoche', 'galoshe']
# Set number  417  of size  2 ['lamellar', 'lamelliform']
# Set number  418  of size  2 ['gabardine', 'gaberdine']
# Set number  419  of size  2 ['ligature', 'ligate']
# Set number  420  of size  2 ['fundamentally', 'radically']
# Set number  421  of size  2 ['fulminating', 'fulminate']
# Set number  422  of size  2 ['fulahs', 'foolahs']
# Set number  423  of size  2 ['fuchsine', 'rosaniline']
# Set number  424  of size  2 ['fruitage', 'fruitery']
# Set number  425  of size  2 ['frouzy', 'frowzy']
# Set number  426  of size  2 ['frostweed', 'rockrose']
# Set number  427  of size  2 ['frontal', 'frontlet']
# Set number  428  of size  2 ['frow', 'frower']
# Set number  429  of size  2 ['freya', 'frigga']
# Set number  430  of size  2 ['freethinker', 'unbeliever']
# Set number  431  of size  2 ['freebootery', 'freebooting']
# Set number  432  of size  3 ['frankpledge', 'friborgh', 'friborg']
# Set number  433  of size  2 ['juror', 'juryman']
# Set number  434  of size  4 ['glucose', 'lactose', 'galactose', 'lactin']
# Set number  435  of size  2 ['jasmine', 'gelsemium']
# Set number  436  of size  3 ['genet', 'genette', 'jennet']
# Set number  437  of size  2 ['fossae', 'fossa']
# Set number  438  of size  2 ['hake', 'gadoid']
# Set number  439  of size  2 ['forel', 'forrill']
# Set number  440  of size  2 ['valvate', 'valvular']
# Set number  441  of size  2 ['footmark', 'footprint']
# Set number  442  of size  3 ['housing', 'houseline', 'saddlecloth']
# Set number  443  of size  2 ['fomites', 'fomes']
# Set number  444  of size  3 ['fluorescein', 'resorcin', 'uranin']
# Set number  445  of size  2 ['uranium', 'uranite']
# Set number  446  of size  2 ['fluorescence', 'fluorescent']
# Set number  447  of size  2 ['fluohydric', 'hydrofluoric']
# Set number  448  of size  6 ['flotsam', 'jetson', 'flotson', 'jetsam', 'jettison', 'ligan']
# Set number  449  of size  2 ['flop', 'flopping']
# Set number  450  of size  2 ['flirt-gill', 'gill-flirt']
# Set number  451  of size  3 ['flinched', 'flinch', 'flinching']
# Set number  452  of size  3 ['flickermouse', 'flittermouse', 'flindermouse']
# Set number  453  of size  2 ['flautist', 'flutist']
# Set number  454  of size  2 ['flasher', 'flusher']
# Set number  455  of size  2 ['flashboard', 'flushboard']
# Set number  456  of size  2 ['flamingoes', 'flamingo']
# Set number  457  of size  2 ['grub', 'grubworm']
# Set number  458  of size  2 ['flabellate', 'flabelliform']
# Set number  459  of size  2 ['flabby', 'flaccid']
# Set number  460  of size  2 ['fish-block', 'fish-tackle']
# Set number  461  of size  2 ['fisetic', 'fisetin']
# Set number  462  of size  3 ['firetail', 'redstart', 'redtail']
# Set number  463  of size  2 ['greensand', 'glauconite']
# Set number  464  of size  2 ['flaw', 'gust']
# Set number  465  of size  2 ['haddock', 'haddie']
# Set number  466  of size  2 ['palmate', 'ricinoleate']
# Set number  467  of size  2 ['ricinoleic', 'ricinolic']
# Set number  468  of size  2 ['finesse', 'finessing']
# Set number  469  of size  2 ['filthily', 'foully']
# Set number  470  of size  2 ['filly', 'foal']
# Set number  471  of size  3 ['filbert', 'hazel', 'hazelnut']
# Set number  472  of size  5 ['kangaroo', 'macropus', 'wallaby', 'pademelon', 'wallabies']
# Set number  473  of size  2 ['figwort', 'scrophularia']
# Set number  474  of size  2 ['fie', 'fy']
# Set number  475  of size  3 ['fibrin', 'fibrinogen', 'fibrinoplastin']
# Set number  476  of size  2 ['fibril', 'fibrilla']
# Set number  477  of size  2 ['renter', 'finedraw']
# Set number  478  of size  6 ['fetich', 'fetishistic', 'fetish', 'fetishism', 'fetichism', 'fetichistic']
# Set number  479  of size  2 ['ferret', 'ferreting']
# Set number  480  of size  2 ['fennec', 'zerda']
# Set number  481  of size  2 ['foxlike', 'foxy']
# Set number  482  of size  2 ['light-footed', 'light-foot']
# Set number  483  of size  2 ['faveolate', 'favose']
# Set number  484  of size  2 ['favas', 'favus']
# Set number  485  of size  2 ['fatuitous', 'fatuous']
# Set number  486  of size  2 ['fatidical', 'fatiloquent']
# Set number  487  of size  2 ['fathead', 'redfish']
# Set number  488  of size  4 ['farsightedness', 'hypermetropy', 'hypermetropia', 'hyperopia']
# Set number  489  of size  3 ['farcy', 'farcin', 'farcimen']
# Set number  490  of size  2 ['gaudy', 'gaud-day']
# Set number  491  of size  3 ['fanfoot', 'gecko', 'geckoes']
# Set number  492  of size  2 ['falcate', 'falcated']
# Set number  493  of size  2 ['fagged', 'fag']
# Set number  494  of size  2 ['faecal', 'fecal']
# Set number  495  of size  2 ['eclipse', 'eclipsed']
# Set number  496  of size  2 ['nip', 'nipping']
# Set number  497  of size  4 ['eccle', 'yaffle', 'hewhole', 'yaffingale']
# Set number  498  of size  2 ['eanling', 'yeanling']
# Set number  499  of size  2 ['furze', 'gorse']
# Set number  500  of size  2 ['ean', 'yean']
# Set number  501  of size  2 ['caliber', 'calibre']
# Set number  502  of size  2 ['calceiform', 'calceolate']
# Set number  503  of size  2 ['larkspur', 'ranunculaceous']
# Set number  504  of size  2 ['calcaneum', 'fibulare']
# Set number  505  of size  2 ['caffeine', 'guaranine']
# Set number  506  of size  2 ['caesura', 'caesural']
# Set number  507  of size  2 ['caddice', 'caddis']
# Set number  508  of size  2 ['cachectic', 'cachectical']
# Set number  509  of size  2 ['caboose', 'galley']
# Set number  510  of size  2 ['cabezon', 'sculpin']
# Set number  511  of size  2 ['reticule', 'reticle']
# Set number  512  of size  2 ['cabal', 'junto']
# Set number  513  of size  3 ['badderlocks', 'henware', 'honeyware']
# Set number  514  of size  2 ['bacteroid', 'bacteroidal']
# Set number  515  of size  2 ['backworm', 'filanders']
# Set number  516  of size  2 ['relapse', 'relapsed']
# Set number  517  of size  2 ['ranunculus', 'ranunculi']
# Set number  518  of size  2 ['bacharach', 'backarack']
# Set number  519  of size  2 ['jovial', 'jolly']
# Set number  520  of size  2 ['baccare', 'backare']
# Set number  521  of size  2 ['babyroussa', 'babyrussa']
# Set number  522  of size  2 ['babylonic', 'babylonical']
# Set number  523  of size  2 ['gallic', 'gallican']
# Set number  524  of size  3 ['gabble', 'gabbling', 'jabber']
# Set number  525  of size  3 ['amaranth', 'amarantus', 'amaranthus']
# Set number  526  of size  2 ['amacratic', 'amasthenic']
# Set number  527  of size  2 ['saxifrage', 'saxifraga']
# Set number  528  of size  2 ['alterability', 'alterableness']
# Set number  529  of size  3 ['alpaca', 'pacos', 'paco']
# Set number  530  of size  2 ['lama', 'lamaism']
# Set number  531  of size  2 ['almug', 'algum']
# Set number  532  of size  2 ['almacantar', 'almucantar']
# Set number  533  of size  4 ['alma', 'almeh', 'alme', 'almah']
# Set number  534  of size  3 ['allopathy', 'heteropathy', 'homeopathy']
# Set number  535  of size  2 ['variability', 'variableness']
# Set number  536  of size  2 ['allodial', 'allodially']
# Set number  537  of size  2 ['allineation', 'alineation']
# Set number  538  of size  3 ['allice', 'allis', 'alose']
# Set number  539  of size  3 ['allium', 'garlic', 'leek']
# Set number  540  of size  3 ['jig', 'jigging', 'jigger']
# Set number  541  of size  2 ['scream', 'screech']
# Set number  542  of size  2 ['rhyme', 'rhymed']
# Set number  543  of size  3 ['allantois', 'allantoidal', 'allantoid']
# Set number  544  of size  2 ['cacodyl', 'alkarsin']
# Set number  545  of size  3 ['fuming', 'fume', 'reek']
# Set number  546  of size  2 ['alisphenoidal', 'alisphenoid']
# Set number  547  of size  2 ['align', 'aline']
# Set number  548  of size  2 ['saracenic', 'saracenical']
# Set number  549  of size  2 ['nickel', 'niccolite']
# Set number  550  of size  2 ['alexandrian', 'alexandrine']
# Set number  551  of size  2 ['aleconner', 'aletaster']
# Set number  552  of size  2 ['alder', 'aller']
# Set number  553  of size  2 ['lawsonia', 'henna']
# Set number  554  of size  2 ['iambic', 'iambus']
# Set number  555  of size  2 ['alcaid', 'alcayde']
# Set number  556  of size  2 ['hemialbumose', 'hemialbumin']
# Set number  557  of size  2 ['albugo', 'leucoma']
# Set number  558  of size  3 ['alalonga', 'albicore', 'alilonghi']
# Set number  559  of size  2 ['alabaster', 'gypsum']
# Set number  560  of size  4 ['gazelle', 'algazel', 'kevin', 'kevel']
# Set number  561  of size  2 ['agrostis', 'redtop']
# Set number  562  of size  2 ['grope', 'groped']
# Set number  563  of size  2 ['aglet', 'aiglet']
# Set number  564  of size  2 ['aggry', 'aggri']
# Set number  565  of size  2 ['aggrieved', 'aggrieve']
# Set number  566  of size  2 ['agglutination', 'agglutinative']
# Set number  567  of size  2 ['agglomerate', 'agglomerated']
# Set number  568  of size  2 ['agendum', 'agenda']
# Set number  569  of size  2 ['agast', 'aghast']
# Set number  570  of size  3 ['amazement', 'amaze', 'amazed']
# Set number  571  of size  2 ['agalmatolite', 'pagodite']
# Set number  572  of size  2 ['fucus', 'rockweed']
# Set number  573  of size  2 ['radiance', 'radiancy']
# Set number  574  of size  2 ['afrit', 'afreet']
# Set number  575  of size  4 ['flickering', 'flicker', 'high-holder', 'yucca']
# Set number  576  of size  2 ['flaunting', 'flaunt']
# Set number  577  of size  2 ['aetites', 'eaglestone']
# Set number  578  of size  4 ['lethargic', 'lethargize', 'lethargy', 'lethargical']
# Set number  579  of size  2 ['aesthetic', 'aesthetical']
# Set number  580  of size  2 ['aerostatic', 'aerostatical']
# Set number  581  of size  3 ['bacteria', 'bacterium', 'bacillus']
# Set number  582  of size  2 ['aeolian', 'aeolic']
# Set number  583  of size  2 ['adverted', 'advert']
# Set number  584  of size  2 ['venturesome', 'venturous']
# Set number  585  of size  2 ['adunc', 'adunque']
# Set number  586  of size  2 ['adventitious', 'adventive']
# Set number  587  of size  2 ['adonist', 'jehovist']
# Set number  588  of size  2 ['affiliation', 'filiation']
# Set number  589  of size  2 ['adenose', 'adenous']
# Set number  590  of size  2 ['addled', 'addle']
# Set number  591  of size  2 ['ad-', 'al-']
# Set number  592  of size  5 ['alcyonaria', 'alcyonacea', 'alcyonium', 'gorgoniacea', 'gorgonacea']
# Set number  593  of size  5 ['gymnastic', 'gymnast', 'gymnastical', 'gymnastics', 'gymnasium']
# Set number  594  of size  2 ['acridity', 'acridness']
# Set number  595  of size  2 ['agouti', 'agouty']
# Set number  596  of size  2 ['nettle', 'urtica']
# Set number  597  of size  2 ['aconitum', 'aconite']
# Set number  598  of size  2 ['acinose', 'acinous']
# Set number  599  of size  2 ['achromaticity', 'achromatism']
# Set number  600  of size  3 ['glycerin', 'glycerol', 'glycerine']
# Set number  601  of size  2 ['ruminate', 'ruminated']
# Set number  602  of size  2 ['acetous', 'acetification']
# Set number  603  of size  2 ['hydatid', 'echinococcus']
# Set number  604  of size  2 ['functionaries', 'functionary']
# Set number  605  of size  3 ['acacias', 'leguminous', 'acacia']
# Set number  606  of size  3 ['abstemious', 'abstemiousness', 'abstinent']
# Set number  607  of size  2 ['negro', 'negroes']
# Set number  608  of size  2 ['abiogenesis', 'abiogeny']
# Set number  609  of size  2 ['abib', 'nisan']
# Set number  610  of size  2 ['abet', 'abetting']
# Set number  611  of size  2 ['goldfinch', 'goldie']
# Set number  612  of size  4 ['hibiscus', 'althea', 'althaea', 'hollyhock']
# Set number  613  of size  2 ['rostrum', 'rostellum']
# Set number  614  of size  3 ['abalone', 'haliotis', 'sea-ear']
# Set number  615  of size  2 ['abscond', 'absconding']
# Set number  616  of size  2 ['hermes', 'herma']
# Set number  617  of size  2 ['vaccinia', 'vaccina']
# Set number  618  of size  2 ['yon', 'yonder']
# Set number  619  of size  2 ['nictitate', 'nictate']

# %% [markdown]
# ## Give the category of each word of a custom user written sentence

# %%
my_sentence = "the german admitted speaking hindi".lower() # please modify this sentence

# %%
for word in my_sentence.split(" "):
    tags = []
    if word in kernel:
        tags.append("Kernel")
    if word in core:
        tags.append("Core")
    for elm in satellites:
        if word in elm[0]:
            tags.append("Satellite")
            break
        
    if(tags==[]):
        print("The word ", word, " is neither in the kernel, the core or a satellite")
    else:
        print("The word ", word, " is in : ", " , ".join(tags))
# Out:
# The word  the  is neither in the kernel, the core or a satellite
# The word  german  is in :  Kernel , Core
# The word  admitted  is in :  Kernel , Core
# The word  speaking  is neither in the kernel, the core or a satellite
# The word  hindi  is in :  Satellite
